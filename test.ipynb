# %%
##############################################

# %%
#select only the first10 rows
import pandas as pd
data =  pd.read_csv('datasets/groupdata.csv')
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 #select only the first10 rows
# ----> 2 import pandas as pd
#       3 data =  pd.read_csv('datasets/groupdata.csv')
#       4 data.head(10)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/compat/__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ...

# %%
# Select only the columns: name, age, group.
data[['name','age','group']]

# %%
# Select all students who are in group A.
data[data.group == 'group A']
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group A    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group A  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group A  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group A  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group A  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group A    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group A    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group A    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group A    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group A    Male   90.5
# ...

# %%
# Select all students with age > 40.
data[data.age > 40]
# Out:
#    roll no       name  age    address    session    group gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group A   Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A   Male   70.5
# 7     MS08     Idrees   51     Multan    MORNING  group A   Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group A   Male   90.5
# 15    MS16  Kakamanna   42     Multan  AFTERNOON  group A   Male   90.5
#
#     subj2  scholarship
# 0    84.4       5000.0
# 1    60.5       6000.0
# 7    76.0       8000.0
# 8    81.3       3500.0
# 15   81.3       3800.0

# %%
# Q5: Select all Female students in group B.
data[(data.group == 'group B' )& (data.gender == 'Female') ]
# Out:
#    roll no     name  age   address    session    group  gender  subj1  subj2  \
# 2     MS03  Shaista   35   Karachi  AFTERNOON  group A  Female   64.9   75.1
# 4     MS05     Zara   40  Peshawer        AFT  group A  Female   65.9   72.8
# 5     MS06    Mohid   16    Lahore    MORNING  group A  Female   69.3   78.6
# 6     MS07    Zobia   40   Sialkot        AFT  group A  Female   90.2    NaN
# 13    MS14     Sara   28    Multan  AFTERNOON  group A  Female   84.1   76.0
# 14    MS15   Fatima   33   Sialkot        AFT  group A  Female   90.5   81.3
#
#     scholarship
# 2        8500.0
# 4        3500.0
# 5           NaN
# 6        4000.0
# 13       8000.0
# 14       3500.0

# %%
#Using .loc, select all rows where session is 'MORNING' and only return the columns:
# name, session, scholarship.
data.loc[data['session']=='MORNING',['name','session','scholarship']]
# Out:
#        name  session  scholarship
# 0      Rauf  MORNING       5000.0
# 5     Mohid  MORNING          NaN
# 7    Idrees  MORNING       8000.0
# 12  Mujahid  MORNING       7000.0

# %%
# 7. Using .iloc[]
# Q7: Using .iloc, return rows 5 to 10 and columns 3 to 6
data.iloc[[5,10],[3,6]]
# Out:
#       address  gender
# 5      Lahore  Female
# 10  Islamabad    Male

# %%
data1 = data.sort_values('subj1')
data1
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group A  Female   64.9
# 4     MS05       Zara   40   Peshawer        AFT  group A  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group A  Female   69.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 0     MS01       Rauf   52     Lahore    MORNING  group A    Male   78.3
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 7     MS08     Idrees   51     Multan    MORNING  group A    Male   84.1
# 13    MS14       Sara   28     Multan  AFTERNOON  group A  Female   84.1
# 6     MS07      Zobia   40    Sialkot        AFT  group A  Female   90.2
# 8     MS09      Jamil   53    Karachi        AFT  group A    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group A    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group A    Male   90.5
# ...

# %%
data2= [data.subj1 > data.subj2]
data2
# Out:
# [0     False
#  1      True
#  2     False
#  3     False
#  4     False
#  5     False
#  6     False
#  7      True
#  8      True
#  9      True
#  10     True
#  11     True
#  12    False
#  13     True
#  14     True
#  15     True
#  dtype: bool]

# %%
data.loc[data.subj1> data.subj2 , ['name', 'subj1', 'subj2' ]]
# Out:
#          name  subj1  subj2
# 1        Arif   70.5   60.5
# 7      Idrees   84.1   76.0
# 8       Jamil   90.5   81.3
# 9      Shahid   90.5   81.3
# 10    Khurram   90.5   81.3
# 11       Maaz   90.5   81.3
# 13       Sara   84.1   76.0
# 14     Fatima   90.5   81.3
# 15  Kakamanna   90.5   81.3

# %%
data.set_index(keys ='roll no')
# Out:
#               name  age    address    session    group  gender  subj1  subj2  \
# roll no
# MS01          Rauf   52     Lahore    MORNING  group A    Male   78.3   84.4
# MS02          Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# MS03       Shaista   35    Karachi  AFTERNOON  group A  Female   64.9   75.1
# MS04        Hadeed   20     Lahore        MOR  group A    Male   82.0   84.3
# MS05          Zara   40   Peshawer        AFT  group A  Female   65.9   72.8
# MS06         Mohid   16     Lahore    MORNING  group A  Female   69.3   78.6
# MS07         Zobia   40    Sialkot        AFT  group A  Female   90.2    NaN
# MS08        Idrees   51     Multan    MORNING  group A    Male   84.1   76.0
# MS09         Jamil   53    Karachi        AFT  group A    Male   90.5   81.3
# MS10        Shahid   38     Lahore  AFTERNOON  group A    Male   90.5   81.3
# MS11       Khurram   35  Islamabad        MOR  group A    Male   90.5   81.3
# ...

# %%
#Xxxxxxxxxxxxxxxxxxxxxxx

# %%
# 1. Select rows based on multiple column values
data[(data.gender == 'Male' )&(data.session.isin(['AFTERNOON', 'AFT']))]
# Out:
#    roll no       name  age    address    session    group gender  subj1  \
# 1     MS02       Arif   51  Islamabad        AFT  group A   Male   70.5
# 8     MS09      Jamil   53    Karachi        AFT  group A   Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group A   Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group A   Male   90.5
# 15    MS16  Kakamanna   42     Multan  AFTERNOON  group A   Male   90.5
#
#     subj2  scholarship
# 1    60.5       6000.0
# 8    81.3       3500.0
# 9    81.3       3800.0
# 11   81.3          NaN
# 15   81.3       3800.0

# %%
# 2 Filter using .isin()
data.loc[data['group'].isin(['group A', 'group C']), ['name', 'group']]
# Out:
#          name    group
# 0        Rauf  group A
# 1        Arif  group A
# 2     Shaista  group A
# 3      Hadeed  group A
# 4        Zara  group A
# 5       Mohid  group A
# 6       Zobia  group A
# 7      Idrees  group A
# 8       Jamil  group A
# 9      Shahid  group A
# 10    Khurram  group A
# 11       Maaz  group A
# 12    Mujahid  group A
# 13       Sara  group A
# 14     Fatima  group A
# 15  Kakamanna  group A
