# %%
import pandas as pd
pd.__version__ , pd.__path__
# Out:
# ('2.3.3',
#  ['/Users/mbouderr/Library/Python/3.9/lib/python/site-packages/pandas'])

# %% [markdown]
# ## modify rows and records in dataframe

# %%
data =  pd.read_csv('datasets/groupdata.csv')
data.head()
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
# 3    MS04   Hadeed   20     Lahore        MOR  group A    Male   82.0   84.3
# 4    MS05     Zara   40   Peshawer        AFT  group D  Female   65.9   72.8
#
#    scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0
# 3       4000.0
# 4       3500.0

# %%
data.shape
# Out:
# (16, 10)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16, step=1)

# %%
data.dtypes
# Out:
# roll no         object
# name            object
# age              int64
# address         object
# session         object
# group           object
# gender          object
# subj1          float64
# subj2          float64
# scholarship    float64
# dtype: object

# %%
data.columns
# Out:
# Index(['roll no', 'name', 'age', 'address', 'session', 'group', 'gender',
#        'subj1', 'subj2', 'scholarship'],
#       dtype='object')

# %%
cat datasets/groupdatawithoutcollables.csv
# Out:
# MS01,Rauf,52,Lahore,MORNING,group C,Male,78.3,84.4,5000
# MS02,Arif,51,Islamabad,AFT,group A,Male,70.5,60.5,6000
# MS03,Shaista,35,Karachi,AFTERNOON,group B,Female,64.9,75.1,8500
# MS04,Hadeed,20,Lahore,MOR,group A,Male,82,84.3,4000
# MS05,Zara,40,Peshawer,AFT,group D,Female,65.9,72.8,3500
# MS06,Mohid,16,Lahore,MORNING,group C,Female,69.3,78.6,
# MS07,Zobia,40,Sialkot,AFT,group B,Female,90.2,,4000
# MS08,Idrees,51,Multan,MORNING,group D,Male,84.1,76,8000
# MS09,Jamil,53,Karachi,AFT,group C,Male,90.5,81.3,3500
# MS10,Shahid,38,Lahore,AFTERNOON,group D,Male,90.5,81.3,3800
# MS11,Khurram,35,Islamabad,MOR,group B,Male,90.5,81.3,6000
# MS12,Maaz,25,Karachi,AFTERNOON,group C,Male,90.5,81.3,
# MS13,Mujahid,18,Lahore,MORNING,group D,Male,,76.5,7000
# MS14,Sara,28,Multan,AFTERNOON,group A,Female,84.1,76,8000
# MS15,Fatima,33,Sialkot,AFT,group C,Female,90.5,81.3,3500
# MS16,Kakamanna,42,Multan,AFTERNOON,group A,Male,90.5,81.3,3800

# %% [markdown]
# ## add name of columns while reading the df

# %%
data = pd.read_csv('datasets/groupdatawithoutcollables.csv', names = ['roll no', 'name', 'age', 'address','session', 'group','gender','subj1', 'subj2', 'scholarship'] )
data.head(3)
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
#
#    scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0

# %%
data =  pd.read_csv('datasets/groupdatawithoutcollables.csv', header = None)
data.head(3)
# Out:
#       0        1   2          3          4        5       6     7     8  \
# 0  MS01     Rauf  52     Lahore    MORNING  group C    Male  78.3  84.4
# 1  MS02     Arif  51  Islamabad        AFT  group A    Male  70.5  60.5
# 2  MS03  Shaista  35    Karachi  AFTERNOON  group B  Female  64.9  75.1
#
#         9
# 0  5000.0
# 1  6000.0
# 2  8500.0

# %%
data.columns = ['roll no', 'name', 'age', 'address','session', 'group','gender','subj1', 'subj2', 'scholarship']

# %%
data
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %%
data.columns
# Out:
# Index(['roll no', 'name', 'age', 'address', 'session', 'group', 'gender',
#        'subj1', 'subj2', 'scholarship'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ' , '_' )

# %%
data
# Out:
#    roll_no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %% [markdown]
# ### upper case lower case

# %%
list = [x.capitalize() for x in data.columns]
data.columns= list
data.head(5)
# Out:
#   Roll_no     Name  Age    Address    Session    Group  Gender  Subj1  Subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
# 3    MS04   Hadeed   20     Lahore        MOR  group A    Male   82.0   84.3
# 4    MS05     Zara   40   Peshawer        AFT  group D  Female   65.9   72.8
#
#    Scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0
# 3       4000.0
# 4       3500.0

# %% [markdown]
# ### rename

# %%
data = pd.read_csv('datasets/groupdata.csv')
data.rename(mapper={'roll no' : 'rollNo'},axis=1 ,inplace= True)
data.columns
# Out:
# Index(['rollNo', 'name', 'age', 'address', 'session', 'group', 'gender',
#        'subj1', 'subj2', 'scholarship'],
#       dtype='object')

# %% [markdown]
# ### change the marks of shaista

# %%
data.loc[data.name == 'Shaista', ['subj1', 'subj2']]
# Out:
#    subj1  subj2
# 2   64.9   75.1

# %%
data.loc[data.name == 'Shaista', ['subj1']] = [101]

# data.loc[data.name == 'Rauf',:]

# %% [markdown]
# ### map function

# %%
df = pd.read_csv('datasets/groupdata.csv')
df.head(3)
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
#
#    scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0

# %%
  df['name'].map(len)
# Out:
# 0     4
# 1     4
# 2     7
# 3     6
# 4     4
# 5     5
# 6     5
# 7     6
# 8     5
# 9     6
# 10    7
# 11    4
# 12    7
# 13    4
# 14    6
# 15    9
# Name: name, dtype: int64

# %%
df = pd.read_csv('datasets/groupdata.csv')
df.head(3)
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
#
#    scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0

# %%
# def func(x):
    # if x <= 50:
    #     return 'Young'
    # else :
    #     return 'old'

df['Young/old'] =  data['age'].map(lambda x: 'young' if x <30 else 'old')
df
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %%
def func2(x):
    if x > 80 :
        return 'Pass'
    else :
        return 'Fail'
df['result'] = ((df['subj1']+df['subj2'])/2).map(func2)
df.head()
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
# 3    MS04   Hadeed   20     Lahore        MOR  group A    Male   82.0   84.3
# 4    MS05     Zara   40   Peshawer        AFT  group D  Female   65.9   72.8
#
#    scholarship Young/old result
# 0       5000.0       old   Pass
# 1       6000.0       old   Fail
# 2       8500.0       old   Fail
# 3       4000.0     young   Pass
# 4       3500.0       old   Fail

# %%
df = pd.read_csv('datasets/groupdata.csv')
df['session']= df['session'].map({'MORNING':'M','AFTERNOON':'A' })  
df
# Out:
#    roll no       name  age    address session    group  gender  subj1  subj2  \
# 0     MS01       Rauf   52     Lahore       M  group C    Male   78.3   84.4
# 1     MS02       Arif   51  Islamabad     NaN  group A    Male   70.5   60.5
# 2     MS03    Shaista   35    Karachi       A  group B  Female   64.9   75.1
# 3     MS04     Hadeed   20     Lahore     NaN  group A    Male   82.0   84.3
# 4     MS05       Zara   40   Peshawer     NaN  group D  Female   65.9   72.8
# 5     MS06      Mohid   16     Lahore       M  group C  Female   69.3   78.6
# 6     MS07      Zobia   40    Sialkot     NaN  group B  Female   90.2    NaN
# 7     MS08     Idrees   51     Multan       M  group D    Male   84.1   76.0
# 8     MS09      Jamil   53    Karachi     NaN  group C    Male   90.5   81.3
# 9     MS10     Shahid   38     Lahore       A  group D    Male   90.5   81.3
# 10    MS11    Khurram   35  Islamabad     NaN  group B    Male   90.5   81.3
# ...

# %% [markdown]
# ### to avoid the Nan value on the other values  we use replace()

# %%
df =  pd.read_csv('datasets/groupdata.csv')
df['session'] =  df['session'].replace({'MORNING':'M','AFTERNOON':'A' })
df[['session']]
# Out:
#    session
# 0        M
# 1      AFT
# 2        A
# 3      MOR
# 4      AFT
# 5        M
# 6      AFT
# 7        M
# 8      AFT
# 9        A
# 10     MOR
# 11       A
# 12       M
# 13       A
# 14     AFT
# 15       A

# %% [markdown]
# ### USE replace() on  entire dataframe

# %%
df =  pd.read_csv('datasets/groupdata.csv')
df.replace({'MORNING':'M','AFTERNOON':'AAAAA' })
# Out:
#    roll no       name  age    address session    group  gender  subj1  subj2  \
# 0     MS01       Rauf   52     Lahore       M  group C    Male   78.3   84.4
# 1     MS02       Arif   51  Islamabad     AFT  group A    Male   70.5   60.5
# 2     MS03    Shaista   35    Karachi   AAAAA  group B  Female   64.9   75.1
# 3     MS04     Hadeed   20     Lahore     MOR  group A    Male   82.0   84.3
# 4     MS05       Zara   40   Peshawer     AFT  group D  Female   65.9   72.8
# 5     MS06      Mohid   16     Lahore       M  group C  Female   69.3   78.6
# 6     MS07      Zobia   40    Sialkot     AFT  group B  Female   90.2    NaN
# 7     MS08     Idrees   51     Multan       M  group D    Male   84.1   76.0
# 8     MS09      Jamil   53    Karachi     AFT  group C    Male   90.5   81.3
# 9     MS10     Shahid   38     Lahore   AAAAA  group D    Male   90.5   81.3
# 10    MS11    Khurram   35  Islamabad     MOR  group B    Male   90.5   81.3
# ...

# %% [markdown]
# ### Apply

# %%
df =  pd.read_csv('datasets/groupdata.csv')
df['name'].apply(len)
# Out:
# 0     4
# 1     4
# 2     7
# 3     6
# 4     4
# 5     5
# 6     5
# 7     6
# 8     5
# 9     6
# 10    7
# 11    4
# 12    7
# 13    4
# 14    6
# 15    9
# Name: name, dtype: int64

# %%
# df['old/young']= df['age'].apply(lambda age : 'old' if age >30 else 'young')

df
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %%
## tajriba nchoufo wach ymkn n7ezo chi bnt 3ndha >18 3am w mojtahidadf
df['mojtahida'] = df[['age','scholarship']].apply(lambda row: 'mojtahida' if (row['age'] > 18 )& (row['scholarship'] < 10000 ) else 'kassola', axis = 1)
df
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %%
df['scholarship'] = df['scholarship'].replace({'NaN' : '15000'})

# %%
import pandas as pd
df =  pd.read_csv('datasets/groupdata.csv')
df.head(1)
# Out:
#   roll no  name  age address  session    group gender  subj1  subj2  \
# 0    MS01  Rauf   52  Lahore  MORNING  group C   Male   78.3   84.4
#
#    scholarship
# 0       5000.0

# %%
newdf = pd.DataFrame(data=[['MS222',100,'london','AFT','group D','Male',55.55, 55.2, 99999]], columns = [ 'roll no' , 'age', 'address', 'session', 'group', 'gender','subj1', 'subj2', 'scholarship'])
newdf
# Out:
#   roll no  age address session    group gender  subj1  subj2  scholarship
# 0   MS222  100  london     AFT  group D   Male  55.55   55.2        99999

# %%
newdf = pd.DataFrame(data=[['charaf','MS222',100,'london','AFT','group D','Male',55.55, 55.2]],
columns = ['name', 'roll no' , 'age', 'address', 'session', 'group', 'gender','subj1', 'subj2'])
newdf
# Out:
#      name roll no  age address session    group gender  subj1  subj2
# 0  charaf   MS222  100  london     AFT  group D   Male  55.55   55.2

# %%
## append is deprecated  we can use concat
df =  pd.concat([df,newdf], ignore_index=True)
df.tail()
# Out:
#    roll no       name  age  address    session    group  gender  subj1  subj2  \
# 12    MS13    Mujahid   18   Lahore    MORNING  group D    Male    NaN   76.5
# 13    MS14       Sara   28   Multan  AFTERNOON  group A  Female  84.10   76.0
# 14    MS15     Fatima   33  Sialkot        AFT  group C  Female  90.50   81.3
# 15    MS16  Kakamanna   42   Multan  AFTERNOON  group A    Male  90.50   81.3
# 16   MS222     charaf  100   london        AFT  group D    Male  55.55   55.2
#
#     scholarship
# 12       7000.0
# 13       8000.0
# 14       3500.0
# 15       3800.0
# 16          NaN

# %% [markdown]
# ### drop a row

# %%
import pandas as pd
df =  pd.read_csv('datasets/groupdata.csv')
df.head(5)
# Out:
#   roll no     name  age    address    session    group  gender  subj1  subj2  \
# 0    MS01     Rauf   52     Lahore    MORNING  group C    Male   78.3   84.4
# 1    MS02     Arif   51  Islamabad        AFT  group A    Male   70.5   60.5
# 2    MS03  Shaista   35    Karachi  AFTERNOON  group B  Female   64.9   75.1
# 3    MS04   Hadeed   20     Lahore        MOR  group A    Male   82.0   84.3
# 4    MS05     Zara   40   Peshawer        AFT  group D  Female   65.9   72.8
#
#    scholarship
# 0       5000.0
# 1       6000.0
# 2       8500.0
# 3       4000.0
# 4       3500.0

# %% [markdown]
# ### drop  row 2  and row 4

# %%
df.drop(index=[2,4],axis =0, inplace = True)
df
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# 12    MS13    Mujahid   18     Lahore    MORNING  group D    Male    NaN
# 13    MS14       Sara   28     Multan  AFTERNOON  group A  Female   84.1
# ...

# %%
dropIndex = df[df['session'] == 'AFT'].index
dropIndex
# Out:
# Index([1, 6, 8, 14], dtype='int64')

# %%
df.drop(index =  dropIndex , inplace = True)
df
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# 12    MS13    Mujahid   18     Lahore    MORNING  group D    Male    NaN
# 13    MS14       Sara   28     Multan  AFTERNOON  group A  Female   84.1
# 15    MS16  Kakamanna   42     Multan  AFTERNOON  group A    Male   90.5
#
#     subj2  scholarship
# 0    84.4       5000.0
# 3    84.3       4000.0
# 5    78.6          NaN
# 7    76.0       8000.0
# 9    81.3       3800.0
# ...

# %% [markdown]
# ### drop col with 2 Nan value

# %%
df.drop(df.columns[df.apply(lambda col : col.isnull().sum())], axis = 1 , inplace = True)

# %% [markdown]
# ### change datatype

# %%
import pandas as pd
df =  pd.read_csv('datasets/groupdata.csv')
df.age.dtype
# Out:
# dtype('int64')

# %%
df['age'] =  df.age.astype(float)

# %%
df.age.dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#    roll no       name   age    address    session    group  gender  subj1  \
# 0     MS01       Rauf  52.0     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif  51.0  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista  35.0    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed  20.0     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara  40.0   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid  16.0     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia  40.0    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees  51.0     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil  53.0    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid  38.0     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram  35.0  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz  25.0    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %% [markdown]
# ### change str to bloean

# %%
df.gender.str.contains('Male')
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# 15     True
# Name: gender, dtype: bool

# %%
df.gender.str.contains('Male').astype(int)
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     0
# 5     0
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# 14    0
# 15    1
# Name: gender, dtype: int64

# %%
df['newGender'] = df.gender.str.contains('Male').astype(int)

# %%
df
# Out:
#    roll no       name   age    address    session    group  gender  subj1  \
# 0     MS01       Rauf  52.0     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif  51.0  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista  35.0    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed  20.0     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara  40.0   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid  16.0     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia  40.0    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees  51.0     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil  53.0    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid  38.0     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram  35.0  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz  25.0    Karachi  AFTERNOON  group C    Male   90.5
# ...

# %% [markdown]
# ## sort a df using sort_values

# %%
import pandas as pd
df =  pd.read_csv('datasets/groupdata.csv')
df1 =  df.sort_values(by=['age', 'scholarship'],ascending=[True,False]).reset_index()

# %%
df1.head(5)
# Out:
#    index roll no     name  age  address    session    group  gender  subj1  \
# 0      5    MS06    Mohid   16   Lahore    MORNING  group C  Female   69.3
# 1     12    MS13  Mujahid   18   Lahore    MORNING  group D    Male    NaN
# 2      3    MS04   Hadeed   20   Lahore        MOR  group A    Male   82.0
# 3     11    MS12     Maaz   25  Karachi  AFTERNOON  group C    Male   90.5
# 4     13    MS14     Sara   28   Multan  AFTERNOON  group A  Female   84.1
#
#    subj2  scholarship
# 0   78.6          NaN
# 1   76.5       7000.0
# 2   84.3       4000.0
# 3   81.3          NaN
# 4   76.0       8000.0

# %% [markdown]
# ### sort value Nan value

# %%
import pandas as pd
df =  pd.read_csv('datasets/groupdata.csv')
df.sort_values(by=['scholarship'], na_position='last')
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 14    MS15     Fatima   33    Sialkot        AFT  group C  Female   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 15    MS16  Kakamanna   42     Multan  AFTERNOON  group A    Male   90.5
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 12    MS13    Mujahid   18     Lahore    MORNING  group D    Male    NaN
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# ...

# %% [markdown]
# ### sort using sort_index()

# %%
df.sort_index()
# Out:
#    roll no       name  age    address    session    group  gender  subj1  \
# 0     MS01       Rauf   52     Lahore    MORNING  group C    Male   78.3
# 1     MS02       Arif   51  Islamabad        AFT  group A    Male   70.5
# 2     MS03    Shaista   35    Karachi  AFTERNOON  group B  Female   64.9
# 3     MS04     Hadeed   20     Lahore        MOR  group A    Male   82.0
# 4     MS05       Zara   40   Peshawer        AFT  group D  Female   65.9
# 5     MS06      Mohid   16     Lahore    MORNING  group C  Female   69.3
# 6     MS07      Zobia   40    Sialkot        AFT  group B  Female   90.2
# 7     MS08     Idrees   51     Multan    MORNING  group D    Male   84.1
# 8     MS09      Jamil   53    Karachi        AFT  group C    Male   90.5
# 9     MS10     Shahid   38     Lahore  AFTERNOON  group D    Male   90.5
# 10    MS11    Khurram   35  Islamabad        MOR  group B    Male   90.5
# 11    MS12       Maaz   25    Karachi  AFTERNOON  group C    Male   90.5
# ...
